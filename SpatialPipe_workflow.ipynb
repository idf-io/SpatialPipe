# %% [markdown]
# # Hartmann2021 dataset
# Single-cell metabolic profiling of human cytotoxic T cells. Nature Biotechnology
#
# Contains single-cell mass cytometry (CyTOF) datasets for metabolic analysis of human whole blood populations, in vitro T cell activation and analysis of metabolic states in human tissues as well as MIBI-TOF multiplexed images and segmented single-cell data of colorectal carcinoma and healthy colon.
#
# - All CyTOF datasets have been manually gated on single, live cells to enable direct import into data analysis software (e.g. R environment)
# - MIBI-TOF images have undergone noise removal as described in Keren et al. (2018)
# - Cell Segmentation masks for MIBI-TOF data contain large non-cellular regions that need to be removed during downstream processing
# - MIBI-TOF derived single-cell data is cell size normalized, arcsinh transformed and percentile normalized and contains manually annotated FlowSOM clustering results

# %% [markdown]
# # Import modules and notebook settings

# %%
# Keep modules updated if they change within the session
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Load modules
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import squidpy as sq
import anndata as ad
import scanpy as sc
import scipy as sp
import scanorama as scan

# Settings
import warnings
warnings.filterwarnings('ignore')
#sc.settings.set_figure_params(dpi=80)

# Print versions
sc.logging.print_header()
print(f"squidpy=={sq.__version__}")
# Out:
# 2023-01-23 00:12:21.053205: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-23 00:12:21.228333: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-23 00:12:21.910743: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-23 00:12:21.910802: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-23 00:12:21.910806: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# scanpy==1.9.1 anndata==0.8.0 umap==0.5.3 numpy==1.22.4 scipy==1.10.0 pandas==1.5.2 scikit-learn==1.2.0 statsmodels==0.13.5 python-igraph==0.10.3 louvain==0.7.1 pynndescent==0.5.8
# squidpy==1.2.3

# %% [markdown]
# # Create AnnData object

# %% [markdown]
# ### Current required structure for seamless functionality:
#
#  - **Root folder** (e.g. Hartmann-2021)
#      - **metadata.xlsx**
#      - **experiment_folder/**        *(e.g. scMEP_MIBI_singlecell)*
#          - **main_matrix.csv**        nested matrix with columns = ['point', 'cell_id', $markers ... , 'center_rowcoord', 'center_colcoord', 'cell_size', 'donor', 'category', 'Cluster', 'library_id']         (e.g. scMEP_MIBI_singlecell.csv)
#          - **image_folder/**        *(e.g. scMEP_MIBI_colon_images)*
#              - **donor_folders/**        1 folder per donor/sample; ==obs['donor'] !!!
#                  - **point/FOV folders**        1 folder per point/FOV; == 'librarary_id'; names must not repeat across donors!; requires['cell_id', 'center_rowcoord', 'center_colcord', 'point', 'donor', 'library_id] *(e.g. Poin21, ..., Point32)*
#                 - image_files.tif        == markers/features/channels; names can repeat across donord; *(e.g. 147_vimentin.tif)*
#          - **segmentation_folder/**        *(e.g. segmentation)*
#               - **segmentation_files.tif**        requires obs['cell_id', 'point', 'donor', 'library_id']; *(e.g. Point1_Label_Map.tif)*

# %% [markdown]
# ## User input

# %%
scale_factor = 400/1024 # Scale factor must be equal between spatial points (`adata.obsm'spatial`) and image (adata.uns['spatial']['PointX']['scalefactors']['tissue_hires_scalef'])

# %% [markdown]
# ### Prepare the data

# %%
# Annotations come in a single matrix
data_unformatted = pd.read_csv("input-data/raw-data/Hartmann-2021/scMEP_MIBI_singlecell/scMEP_MIBI_singlecell.csv")
data_unformatted = data_unformatted.dropna(axis=0)

# Some manual matrix formatting
data_unformatted['library_id'] = 'Point' + data_unformatted['point'].astype(str)
data_unformatted['new_index'] = data_unformatted['library_id'].astype(str) + '_' + data_unformatted['cell_id'].astype(str)
data_unformatted = data_unformatted.set_index(pd.Index(data_unformatted['new_index'].to_numpy()))
data_unformatted = data_unformatted.drop('new_index', axis=1)
# Data point coordinates can be converted to using specific scalefactor e.g. 400um/1024px but current workflow relies on then being in the pixel space
# data_unformatted['center_colcoord'] = data_unformatted['center_colcoord'].apply(lambda x: 400 / 1024 * x)
# data_unformatted['center_rowcoord'] = data_unformatted['center_rowcoord'].apply(lambda x: 400 / 1024 * x)

# Subset and format to adjust to AnnData format
counts = data_unformatted.iloc[:, 3:39].copy()

## Due to AnnData bugs (2022-12-05) we need to either supply a numpy.array or recently created pandas.DataFrame
X = pd.DataFrame(
        counts.to_numpy(),
        columns = list(counts.columns),
        index = list(counts.index)
)
obs = data_unformatted.iloc[:, np.r_[0:3, 39:len(data_unformatted.columns)]].copy()

# adata.obsm: Spatial location of spots
obsm = {
    'spatial': data_unformatted.loc[:, ['center_colcoord', 'center_rowcoord']].to_numpy()
}

# adata.uns: Metadata
sample_info = pd.read_excel(
    "input-data/raw-data/Hartmann-2021/scMEP_sample_description.xlsx",
).to_dict(orient='list')

uns = {
    'sample_info': sample_info,
    'Cluster_colors': [
        '#1f77b4',
        '#ff7f0e',
        '#2ca02c',
        '#d62728',
        '#9467bd',
        '#8c564b',
        '#e377c2',
        '#7f7f7f'
      ]
}

# %% [markdown]
# ### Create the object

# %%
# Create AnnData object
adata = ad.AnnData(
    X = X, 
    obs = obs, 
    obsm = obsm,
    uns = uns
)

# Remove observations that belong to an empyt point
adata = adata[~np.isnan(adata.obsm["spatial"][:, 0])].copy()

# %% [markdown]
# ### View

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 63734 × 36
#     obs: 'row_num', 'point', 'cell_id', 'X1', 'center_rowcoord', 'center_colcoord', 'cell_size', 'category', 'donor', 'Cluster', 'library_id'
#     uns: 'sample_info', 'Cluster_colors'
#     obsm: 'spatial'

# %%
adata.to_df()
# Out:
#                     H3  vimentin       SMA      CD98     NRF2p       CD4  \
# Point7_2      0.785881  0.408300  0.696414  0.000000  0.600454  0.000000
# Point7_6      0.762130  0.727941  0.692685  0.000000  0.126400  0.000000
# Point7_8      0.718484  0.321032  0.270971  0.379427  0.728447  0.239057
# Point7_9      0.844099  0.595707  0.643885  0.334527  0.134485  0.531027
# Point7_14     0.733856  0.652953  0.461541  0.589736  0.484765  0.356065
# ...                ...       ...       ...       ...       ...       ...
# Point25_1124  0.606688  0.693328  0.482057  0.000000  0.417442  0.348995
# Point25_1125  0.803571  0.704590  0.541540  0.543553  0.276144  0.571832
# Point25_1126  0.748780  0.485276  0.868089  0.000000  0.525238  0.263389
# Point25_1127  0.831164  0.812797  0.561337  0.101062  0.578004  0.136832
# Point25_1128  0.832389  0.566054  0.497770  0.279935  0.620042  0.358271
#
#                   CD14      CD45       PD1      CD31  ...       CD8      CD57  \
# Point7_2      0.572489  0.071873  0.000000  0.000000  ...  0.000000  0.000000
# Point7_6      0.330630  0.474050  0.000000  0.000000  ...  0.468677  0.070334
# Point7_8      0.131221  0.192857  0.000000  0.000000  ...  0.033525  0.157202
# Point7_9      0.195556  0.670235  0.053552  0.000000  ...  0.114762  0.000000
# Point7_14     0.386779  0.439137  0.000000  0.287635  ...  0.019767  0.000000
# ...                ...       ...       ...       ...  ...       ...       ...
# Point25_1124  0.499925  0.209032  0.000000  0.000000  ...  0.000000  0.000000
# Point25_1125  0.672874  0.727685  0.563716  0.000000  ...  0.000000  0.000000
# Point25_1126  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# Point25_1127  0.034396  0.000000  0.000000  0.885439  ...  0.000000  0.000000
# Point25_1128  0.488144  0.246632  0.000000  0.000000  ...  0.000000  0.000000
#
#                   LDHA      IDH2       HK1      Ecad     CPT1A        CK  \
# Point7_2      0.344579  0.502285  0.161829  0.269818  0.324649  0.000000
# Point7_6      0.409235  0.481462  0.312938  0.094715  0.354284  0.000000
# Point7_8      0.537986  0.543015  0.091759  0.322762  0.443656  0.284286
# Point7_9      0.609270  0.499102  0.479794  0.294011  0.444598  0.000000
# Point7_14     0.618623  0.557943  0.384368  0.477327  0.559286  0.396537
# ...                ...       ...       ...       ...       ...       ...
# Point25_1124  0.648503  0.507011  0.117075  0.351623  0.378172  0.000000
# Point25_1125  0.663256  0.624918  0.662077  0.394823  0.406933  0.000000
# Point25_1126  0.599062  0.625642  0.426509  0.393277  0.447733  0.000000
# Point25_1127  0.650302  0.668709  0.349704  0.379485  0.453863  0.000000
# Point25_1128  0.663211  0.505957  0.215997  0.234392  0.558448  0.000000
#
#               NaKATPase     HIF1A
# Point7_2       0.000000  0.000000
# Point7_6       0.000000  0.000000
# Point7_8       0.447547  0.000000
# Point7_9       0.256981  0.106809
# Point7_14      0.682852  0.204079
# ...                 ...       ...
# Point25_1124   0.459636  0.000000
# Point25_1125   0.494732  0.000000
# Point25_1126   0.000000  0.000000
# Point25_1127   0.336142  0.000000
# Point25_1128   0.040020  0.000000
#
# [63734 rows x 36 columns]

# %%
adata.obs
# Out:
#               row_num  point  cell_id       X1  center_rowcoord  \
# Point7_2            0      7        2  63894.0            109.0
# Point7_6            3      7        6  63898.0            845.0
# Point7_8            4      7        8  63900.0            997.0
# Point7_9            5      7        9  63901.0            192.0
# Point7_14           9      7       14  63906.0            913.0
# ...               ...    ...      ...      ...              ...
# Point25_1124    66394     25     1124  50571.0            890.0
# Point25_1125    66395     25     1125  50572.0            492.0
# Point25_1126    66396     25     1126  50573.0            618.0
# Point25_1127    66397     25     1127  50574.0             65.0
# Point25_1128    66398     25     1128  50575.0            933.0
#
#               center_colcoord  cell_size   category donor       Cluster  \
# Point7_2                  6.0      277.0  carcinoma  90de     Imm_other
# Point7_6                  5.0      298.0  carcinoma  90de     Imm_other
# Point7_8                 17.0     2037.0  carcinoma  90de    Epithelial
# Point7_9                 13.0      611.0  carcinoma  90de     Tcell_CD4
# Point7_14                17.0     1616.0  carcinoma  90de  Myeloid_CD68
# ...                       ...        ...        ...   ...           ...
# Point25_1124           1016.0      219.0  carcinoma  21d7     Imm_other
# Point25_1125           1018.0      238.0  carcinoma  21d7     Tcell_CD4
# Point25_1126           1019.0      283.0  carcinoma  21d7    Fibroblast
# Point25_1127           1019.0      138.0  carcinoma  21d7   Endothelial
# Point25_1128           1019.0      110.0  carcinoma  21d7     Imm_other
#
#              library_id
# Point7_2         Point7
# Point7_6         Point7
# Point7_8         Point7
# Point7_9         Point7
# Point7_14        Point7
# ...                 ...
# Point25_1124    Point25
# Point25_1125    Point25
# Point25_1126    Point25
# Point25_1127    Point25
# Point25_1128    Point25
#
# [63734 rows x 11 columns]

# %% [markdown]
# # Preprocessing

# %%
# Correct batches (Points) | Inspiration from Squidpy preprocessing pipeline "https://github.com/theislab/squidpy_reproducibility/blob/master/notebooks/prepare_data/ionpath.ipynb"
def splitBatches(adata, batch, hvg=None):
    split = []
    if hvg is not None:
        adata = adata[:, hvg]
    for i in adata.obs[batch].unique():
        adata_split = adata[adata.obs[batch] == i].copy()
        adata_split.X = sp.sparse.csr_matrix(adata_split.X.copy())
        sc.pp.scale(adata_split)
        split.append(adata_split)
    return split

# %%
# Correction
split = splitBatches(adata, batch="point")
corrected_list = scan.correct_scanpy(split, return_dimred=True)

corrected = corrected_list[0].concatenate(
    corrected_list[1:]
)

adata = corrected.copy()
# Out:
# Found 36 genes among all datasets
# [[0.         0.0751604  0.07395498 ... 0.39257593 0.19890009 0.00641613]
#  [0.         0.         0.14790997 ... 0.01799775 0.05       0.21743389]
#  [0.         0.         0.         ... 0.05466238 0.06430868 0.07395498]
#  ...
#  [0.         0.         0.         ... 0.         0.46344207 0.04611924]
#  [0.         0.         0.         ... 0.         0.         0.06078431]
#  [0.         0.         0.         ... 0.         0.         0.        ]]
# Processing datasets (37, 55)
# Processing datasets (5, 8)
# Processing datasets (0, 5)
# Processing datasets (5, 22)
# Processing datasets (0, 9)
# Processing datasets (22, 24)
# Processing datasets (0, 22)
# Processing datasets (54, 55)
# Processing datasets (1, 3)
# Processing datasets (18, 24)
# Processing datasets (8, 22)
# Processing datasets (27, 31)
# Processing datasets (8, 24)
# Processing datasets (7, 20)
# Processing datasets (24, 56)
# Processing datasets (49, 51)
# Processing datasets (0, 37)
# Processing datasets (11, 12)
# Processing datasets (37, 54)
# Processing datasets (50, 51)
# Processing datasets (12, 19)
# Processing datasets (4, 16)
# Processing datasets (5, 37)
# Processing datasets (29, 43)
# Processing datasets (55, 56)
# Processing datasets (0, 8)
# Processing datasets (29, 30)
# Processing datasets (1, 38)
# Processing datasets (39, 47)
# Processing datasets (27, 33)
# Processing datasets (31, 33)
# Processing datasets (39, 40)
# Processing datasets (10, 28)
# Processing datasets (31, 39)
# Processing datasets (33, 44)
# Processing datasets (25, 27)
# Processing datasets (22, 56)
# Processing datasets (35, 38)
# Processing datasets (39, 53)
# Processing datasets (0, 55)
# Processing datasets (23, 35)
# Processing datasets (4, 12)
# Processing datasets (24, 37)
# Processing datasets (30, 43)
# Processing datasets (22, 37)
# Processing datasets (22, 55)
# Processing datasets (4, 11)
# Processing datasets (5, 55)
# Processing datasets (11, 16)
# Processing datasets (8, 56)
# Processing datasets (5, 24)
# Processing datasets (3, 4)
# Processing datasets (8, 37)
# Processing datasets (35, 57)
# Processing datasets (24, 54)
# Processing datasets (52, 53)
# Processing datasets (13, 14)
# Processing datasets (9, 37)
# Processing datasets (31, 47)
# Processing datasets (18, 54)
# Processing datasets (27, 44)
# Processing datasets (5, 54)
# Processing datasets (24, 55)
# Processing datasets (47, 53)
# Processing datasets (27, 39)
# Processing datasets (39, 44)
# Processing datasets (6, 29)
# Processing datasets (27, 32)
# Processing datasets (48, 53)
# Processing datasets (44, 47)
# Processing datasets (4, 19)
# Processing datasets (1, 35)
# Processing datasets (8, 55)
# Processing datasets (11, 19)
# Processing datasets (38, 44)
# Processing datasets (16, 49)
# Processing datasets (1, 27)
# Processing datasets (9, 55)
# Processing datasets (32, 39)
# Processing datasets (10, 12)
# Processing datasets (4, 49)
# Processing datasets (33, 38)
# Processing datasets (12, 36)
# Processing datasets (5, 9)
# Processing datasets (6, 43)
# Processing datasets (4, 10)
# Processing datasets (27, 47)
# Processing datasets (44, 51)
# Processing datasets (28, 48)
# Processing datasets (12, 16)
# Processing datasets (19, 33)
# Processing datasets (44, 49)
# Processing datasets (29, 41)
# Processing datasets (25, 33)
# Processing datasets (36, 49)
# Processing datasets (33, 39)
# Processing datasets (31, 32)
# Processing datasets (31, 44)
# Processing datasets (16, 19)
# Processing datasets (27, 38)
# Processing datasets (3, 38)
# Processing datasets (32, 33)
# Processing datasets (25, 51)
# Processing datasets (0, 24)
# Processing datasets (16, 36)
# Processing datasets (44, 48)
# Processing datasets (21, 25)
# Processing datasets (6, 41)
# Processing datasets (38, 57)
# Processing datasets (16, 21)
# Processing datasets (5, 56)
# Processing datasets (12, 28)
# Processing datasets (12, 23)
# Processing datasets (49, 50)
# Processing datasets (22, 54)
# Processing datasets (19, 36)
# Processing datasets (19, 35)
# Processing datasets (19, 27)
# Processing datasets (10, 19)
# Processing datasets (11, 36)
# Processing datasets (47, 48)
# Processing datasets (4, 36)
# Processing datasets (38, 39)
# Processing datasets (25, 31)
# Processing datasets (15, 39)
# Processing datasets (1, 21)
# Processing datasets (23, 57)
# Processing datasets (54, 56)
# Processing datasets (5, 18)
# Processing datasets (0, 18)
# Processing datasets (19, 49)
# Processing datasets (26, 27)
# Processing datasets (12, 49)
# Processing datasets (10, 11)
# Processing datasets (43, 46)
# Processing datasets (33, 50)
# Processing datasets (33, 35)
# Processing datasets (23, 46)
# Processing datasets (1, 31)
# Processing datasets (21, 28)
# Processing datasets (4, 28)
# Processing datasets (15, 27)
# Processing datasets (14, 45)
# Processing datasets (25, 49)
# Processing datasets (25, 44)
# Processing datasets (1, 33)
# Processing datasets (41, 43)
# Processing datasets (4, 21)
# Processing datasets (33, 34)
# Processing datasets (10, 48)
# Processing datasets (21, 38)
# Processing datasets (32, 53)
# Processing datasets (49, 57)
# Processing datasets (48, 57)
# Processing datasets (1, 4)
# Processing datasets (5, 6)
# Processing datasets (40, 47)
# Processing datasets (19, 25)
# Processing datasets (28, 34)
# Processing datasets (27, 35)
# Processing datasets (38, 48)
# Processing datasets (53, 57)
# Processing datasets (8, 18)
# Processing datasets (27, 53)
# Processing datasets (34, 36)
# Processing datasets (4, 51)
# Processing datasets (28, 36)
# Processing datasets (44, 57)
# Processing datasets (12, 35)
# Processing datasets (6, 7)
# Processing datasets (48, 49)
# Processing datasets (38, 49)
# Processing datasets (1, 25)
# Processing datasets (9, 29)
# Processing datasets (35, 36)
# Processing datasets (14, 20)
# Processing datasets (1, 44)
# Processing datasets (37, 56)
# Processing datasets (36, 44)
# Processing datasets (12, 25)
# Processing datasets (33, 36)
# Processing datasets (33, 51)
# Processing datasets (28, 33)
# Processing datasets (32, 35)
# Processing datasets (33, 48)
# Processing datasets (33, 47)
# Processing datasets (39, 48)
# Processing datasets (9, 42)
# Processing datasets (3, 10)
# Processing datasets (1, 19)
# Processing datasets (47, 49)
# Processing datasets (31, 38)
# Processing datasets (38, 47)
# Processing datasets (35, 44)
# Processing datasets (44, 50)
# Processing datasets (9, 22)
# Processing datasets (19, 28)
# Processing datasets (35, 46)
# Processing datasets (32, 38)
# Processing datasets (10, 25)
# Processing datasets (33, 49)
# Processing datasets (40, 50)
# Processing datasets (8, 54)
# Processing datasets (36, 40)
# Processing datasets (40, 53)
# Processing datasets (3, 12)
# Processing datasets (36, 51)
# Processing datasets (36, 39)
# Processing datasets (7, 14)
# Processing datasets (27, 34)
# Processing datasets (36, 47)
# Processing datasets (47, 52)
# Processing datasets (32, 44)
# Processing datasets (35, 39)
# Processing datasets (0, 54)
# Processing datasets (3, 25)
# Processing datasets (3, 16)
# Processing datasets (16, 51)
# Processing datasets (1, 12)
# Processing datasets (16, 25)
# Processing datasets (20, 29)
# Processing datasets (39, 52)
# Processing datasets (16, 28)
# Processing datasets (44, 53)
# Processing datasets (1, 10)
# Processing datasets (35, 49)
# Processing datasets (9, 43)
# Processing datasets (33, 57)
# Processing datasets (20, 30)
# Processing datasets (10, 33)
# Processing datasets (10, 21)
# Processing datasets (6, 9)
# Processing datasets (38, 53)
# Processing datasets (32, 47)
# Processing datasets (25, 28)
# Processing datasets (18, 55)
# Processing datasets (18, 22)
# Processing datasets (10, 16)
# Processing datasets (36, 48)
# Processing datasets (19, 23)
# Processing datasets (4, 25)
# Processing datasets (3, 35)
# Processing datasets (19, 21)
# Processing datasets (15, 42)
# Processing datasets (1, 15)
# Processing datasets (6, 20)
# Processing datasets (12, 34)
# Processing datasets (3, 21)
# Processing datasets (35, 40)
# Processing datasets (51, 57)
# Processing datasets (21, 27)
# Processing datasets (34, 44)
# Processing datasets (27, 40)
# Processing datasets (11, 48)
# Processing datasets (14, 22)
# Processing datasets (32, 34)
# Processing datasets (35, 47)
# Processing datasets (21, 34)
# Processing datasets (39, 57)
# Processing datasets (1, 57)
# Processing datasets (21, 36)
# Processing datasets (21, 35)
# Processing datasets (25, 39)
# Processing datasets (19, 34)
# Processing datasets (36, 57)
# Processing datasets (46, 57)
# Processing datasets (48, 52)
# Processing datasets (42, 55)
# Processing datasets (11, 28)
# Processing datasets (3, 27)
# Processing datasets (28, 49)
# Processing datasets (12, 27)
# Processing datasets (39, 49)
# Processing datasets (48, 51)
# Processing datasets (25, 38)
# Processing datasets (35, 53)
# Processing datasets (13, 45)
# Processing datasets (18, 37)
# Processing datasets (9, 14)
# Processing datasets (35, 48)
# Processing datasets (12, 21)
# Processing datasets (19, 31)
# Processing datasets (19, 44)
# Processing datasets (10, 27)
# Processing datasets (19, 38)
# Processing datasets (15, 38)
# Processing datasets (39, 42)
# Processing datasets (32, 48)
# Processing datasets (42, 45)
# Processing datasets (39, 50)
# Processing datasets (31, 53)
# Processing datasets (6, 30)
# Processing datasets (21, 51)
# Processing datasets (3, 49)
# Processing datasets (1, 23)
# Processing datasets (28, 51)
# Processing datasets (2, 53)
# Processing datasets (7, 29)
# Processing datasets (34, 49)
# Processing datasets (31, 36)
# Processing datasets (40, 44)
# Processing datasets (12, 43)
# Processing datasets (15, 53)
# Processing datasets (27, 36)
# Processing datasets (36, 46)
# Processing datasets (7, 30)
# Processing datasets (38, 40)
# Processing datasets (1, 32)
# Processing datasets (37, 42)
# Processing datasets (10, 34)
# Processing datasets (0, 6)
# Processing datasets (31, 35)
# Processing datasets (19, 57)
# Processing datasets (53, 56)
# Processing datasets (32, 40)
# Processing datasets (26, 31)
# Processing datasets (0, 56)
# Processing datasets (31, 48)
# Processing datasets (34, 48)
# Processing datasets (17, 27)
# Processing datasets (11, 25)
# Processing datasets (21, 49)
# Processing datasets (9, 30)
# Processing datasets (27, 48)
# Processing datasets (48, 50)
# Processing datasets (38, 51)
# Processing datasets (25, 34)
# Processing datasets (25, 36)
# Processing datasets (24, 27)
# Processing datasets (3, 19)
# Processing datasets (1, 16)
# Processing datasets (8, 9)
# Processing datasets (2, 39)
# Processing datasets (7, 8)
# Processing datasets (11, 43)
# Processing datasets (19, 51)
# Processing datasets (33, 40)
# Processing datasets (46, 48)
# Processing datasets (12, 33)
# Processing datasets (0, 29)
# Processing datasets (34, 35)
# Processing datasets (26, 39)
# Processing datasets (30, 41)
# Processing datasets (22, 41)
# Processing datasets (12, 51)
# Processing datasets (21, 44)
# Processing datasets (14, 29)
# Processing datasets (40, 49)
# Processing datasets (12, 57)
# Processing datasets (11, 49)
# Processing datasets (1, 48)
# Processing datasets (23, 36)
# Processing datasets (51, 53)
# Processing datasets (33, 53)
# Processing datasets (22, 29)
# Processing datasets (12, 44)
# Processing datasets (16, 30)
# Processing datasets (31, 49)
# Processing datasets (36, 38)
# Processing datasets (10, 44)
# Processing datasets (28, 44)
# Processing datasets (40, 48)
# Processing datasets (34, 39)
# Processing datasets (23, 27)
# Processing datasets (34, 45)
# Processing datasets (15, 31)
# Processing datasets (32, 36)
# Processing datasets (28, 31)
# Processing datasets (27, 50)
# Processing datasets (25, 35)
# Processing datasets (38, 50)
# Processing datasets (15, 33)
# Processing datasets (28, 40)
# Processing datasets (28, 35)
# Processing datasets (27, 52)
# Processing datasets (3, 33)
# Processing datasets (13, 18)
# Processing datasets (4, 34)
# Processing datasets (2, 27)
# Processing datasets (2, 15)
# Processing datasets (10, 36)
# Processing datasets (3, 28)
# Processing datasets (25, 48)
# Processing datasets (34, 57)
# Processing datasets (10, 49)
# Processing datasets (12, 15)
# Processing datasets (10, 15)
# Processing datasets (27, 28)
# Processing datasets (1, 39)
# Processing datasets (6, 8)
# Processing datasets (34, 51)
# Processing datasets (49, 53)
# Processing datasets (21, 33)
# Processing datasets (25, 50)
# Processing datasets (3, 44)
# Processing datasets (27, 51)
# Processing datasets (10, 31)
# Processing datasets (2, 3)
# Processing datasets (43, 49)
# Processing datasets (27, 49)
# Processing datasets (11, 35)
# Processing datasets (11, 23)
# Processing datasets (1, 11)
# Processing datasets (45, 55)
# Processing datasets (21, 48)
# Processing datasets (19, 48)
# Processing datasets (8, 27)
# Processing datasets (11, 29)
# Processing datasets (3, 51)
# Processing datasets (34, 38)
# Processing datasets (12, 48)
# Processing datasets (23, 38)
# Processing datasets (16, 34)
# Processing datasets (31, 57)
# Processing datasets (9, 13)
# Processing datasets (47, 57)
# Processing datasets (25, 32)
# Processing datasets (42, 48)
# Processing datasets (4, 43)
# Processing datasets (3, 23)
# Processing datasets (2, 23)
# Processing datasets (2, 13)
# Processing datasets (39, 51)
# Processing datasets (38, 42)
# Processing datasets (3, 11)
# Processing datasets (31, 34)
# Processing datasets (4, 33)
# Processing datasets (47, 51)
# Processing datasets (23, 28)
# Processing datasets (42, 49)
# Processing datasets (2, 32)
# Processing datasets (36, 42)
# Processing datasets (36, 43)
# Processing datasets (5, 14)
# Processing datasets (26, 33)
# Processing datasets (10, 23)
# Processing datasets (32, 57)
# Processing datasets (30, 46)
# Processing datasets (40, 51)
# Processing datasets (6, 11)
# Processing datasets (15, 23)
# Processing datasets (1, 49)
# Processing datasets (40, 57)
# Processing datasets (2, 12)
# Processing datasets (23, 25)
# Processing datasets (4, 35)
# Processing datasets (17, 48)
# Processing datasets (19, 32)
# Processing datasets (1, 47)
# Processing datasets (9, 24)
# Processing datasets (25, 40)
# Processing datasets (21, 39)
# Processing datasets (19, 39)
# Processing datasets (16, 38)
# Processing datasets (1, 28)
# Processing datasets (6, 22)
# Processing datasets (27, 57)
# Processing datasets (21, 23)
# Processing datasets (1, 53)
# Processing datasets (40, 42)
# Processing datasets (12, 38)
# Processing datasets (2, 10)
# Processing datasets (32, 52)
# Processing datasets (23, 33)
# Processing datasets (12, 32)
# Processing datasets (31, 51)
# Processing datasets (17, 39)
# Processing datasets (10, 32)
# Processing datasets (7, 9)
# Processing datasets (25, 47)
# Processing datasets (43, 55)
# Processing datasets (10, 51)
# Processing datasets (35, 42)
# Processing datasets (3, 34)
# Processing datasets (17, 25)
# Processing datasets (10, 17)
# Processing datasets (9, 54)
# Processing datasets (15, 32)
# Processing datasets (15, 19)
# Processing datasets (11, 34)
# Processing datasets (5, 29)
# Processing datasets (35, 43)
# Processing datasets (46, 49)
# Processing datasets (11, 21)
# Processing datasets (50, 57)
# Processing datasets (10, 35)
# Processing datasets (10, 38)
# Processing datasets (28, 32)
# Processing datasets (21, 31)
# Processing datasets (1, 42)
# Processing datasets (15, 25)
# Processing datasets (4, 44)
# Processing datasets (8, 14)
# Processing datasets (6, 14)
# Processing datasets (2, 48)
# Processing datasets (50, 53)
# Processing datasets (28, 38)
# Processing datasets (42, 53)
# Processing datasets (13, 17)
# Processing datasets (0, 43)
# Processing datasets (23, 40)
# Processing datasets (35, 51)
# Processing datasets (16, 27)
# Processing datasets (34, 40)
# Processing datasets (29, 55)
# Processing datasets (38, 46)
# Processing datasets (1, 2)
# Processing datasets (42, 43)
# Processing datasets (16, 43)
# Processing datasets (1, 51)
# Processing datasets (9, 18)
# Processing datasets (30, 36)
# Processing datasets (4, 30)
# Processing datasets (17, 31)
# Processing datasets (48, 56)
# Processing datasets (4, 27)
# Processing datasets (14, 55)
# Processing datasets (30, 42)
# Processing datasets (4, 6)
# Processing datasets (23, 32)
# Processing datasets (9, 11)
# Processing datasets (44, 46)
# Processing datasets (28, 57)
# Processing datasets (22, 27)
# Processing datasets (36, 50)
# Processing datasets (37, 41)
# Processing datasets (15, 35)
# Processing datasets (13, 22)
# Processing datasets (23, 44)
# Processing datasets (20, 43)
# Processing datasets (28, 39)
# Processing datasets (36, 53)
# Processing datasets (42, 44)
# Processing datasets (19, 47)
# Processing datasets (17, 33)
# Processing datasets (21, 40)
# Processing datasets (11, 30)
# Processing datasets (40, 52)
# Processing datasets (11, 33)
# Processing datasets (11, 27)
# Processing datasets (31, 40)
# Processing datasets (40, 46)
# Processing datasets (6, 16)
# Processing datasets (9, 20)
# Processing datasets (22, 45)
# Processing datasets (12, 40)
# Processing datasets (26, 32)
# Processing datasets (43, 48)
# Processing datasets (15, 47)
# Processing datasets (14, 54)
# Processing datasets (23, 31)
# Processing datasets (3, 13)
# Processing datasets (7, 55)
# Processing datasets (7, 41)
# Processing datasets (42, 46)
# Processing datasets (16, 35)
# Processing datasets (4, 23)
# Processing datasets (15, 17)
# Processing datasets (2, 40)
# Processing datasets (16, 33)
# Processing datasets (13, 23)
# Processing datasets (12, 31)
# Processing datasets (3, 36)
# Processing datasets (20, 41)
# Processing datasets (12, 42)
# Processing datasets (9, 10)
# Processing datasets (28, 47)
# Processing datasets (15, 44)
# Processing datasets (23, 39)
# Processing datasets (43, 51)
# Processing datasets (31, 52)
# Processing datasets (24, 39)
# Processing datasets (16, 44)
# Processing datasets (34, 50)
# Processing datasets (15, 48)
# Processing datasets (13, 15)
# Processing datasets (41, 55)
# Processing datasets (33, 42)
# Processing datasets (25, 30)
# Processing datasets (12, 30)
# Processing datasets (5, 7)
# Processing datasets (15, 40)
# Processing datasets (32, 42)
# Processing datasets (13, 32)
# Processing datasets (1, 36)
# Processing datasets (4, 38)
# Processing datasets (1, 50)
# Processing datasets (18, 53)
# Processing datasets (17, 18)
# Processing datasets (41, 48)
# Processing datasets (3, 48)
# Processing datasets (4, 32)
# Processing datasets (3, 32)
# Processing datasets (29, 46)
# Processing datasets (29, 37)
# Processing datasets (47, 50)
# Processing datasets (34, 47)
# Processing datasets (16, 48)
# Processing datasets (23, 48)
# Processing datasets (16, 23)
# Processing datasets (30, 49)
# Processing datasets (30, 35)
# Processing datasets (25, 57)
# Processing datasets (3, 39)
# Processing datasets (7, 11)
# Processing datasets (0, 7)
# Processing datasets (13, 34)
# Processing datasets (14, 41)
# Processing datasets (32, 49)
# Processing datasets (20, 22)
# Processing datasets (19, 43)
# Processing datasets (7, 37)
# Processing datasets (10, 57)
# Processing datasets (3, 31)
# Processing datasets (21, 42)
# Processing datasets (38, 52)
# Processing datasets (24, 31)
# Processing datasets (3, 57)
# Processing datasets (28, 46)
# Processing datasets (12, 46)
# Processing datasets (34, 42)
# Processing datasets (5, 41)
# Processing datasets (50, 56)
# Processing datasets (39, 56)
# Processing datasets (41, 54)
# Processing datasets (2, 31)
# Processing datasets (42, 51)
# Processing datasets (23, 34)
# Processing datasets (16, 29)
# Processing datasets (42, 50)
# Processing datasets (12, 47)
# Processing datasets (4, 48)
# Processing datasets (11, 51)
# Processing datasets (11, 31)
# Processing datasets (51, 52)
# Processing datasets (15, 52)
# Processing datasets (3, 50)
# Processing datasets (19, 40)
# Processing datasets (2, 9)
# Processing datasets (13, 20)
# Processing datasets (10, 47)
# Processing datasets (45, 54)
# Processing datasets (1, 13)
# Processing datasets (14, 34)
# Processing datasets (14, 24)
# Processing datasets (7, 13)
# Processing datasets (1, 34)
# Processing datasets (23, 53)
# Processing datasets (35, 50)
# Processing datasets (42, 52)
# Processing datasets (34, 53)
# Processing datasets (4, 31)
# Processing datasets (22, 39)
# Processing datasets (7, 10)
# Processing datasets (4, 7)
# Processing datasets (41, 49)
# Processing datasets (8, 41)
# Processing datasets (4, 29)
# Processing datasets (23, 49)
# Processing datasets (11, 39)
# Processing datasets (28, 50)
# Processing datasets (45, 56)
# Processing datasets (53, 55)
# Processing datasets (7, 22)
# Processing datasets (14, 43)
# Processing datasets (8, 29)
# Processing datasets (25, 42)
# Processing datasets (4, 9)
# Processing datasets (17, 47)
# Processing datasets (20, 55)
# Processing datasets (36, 41)
# Processing datasets (46, 51)
# Processing datasets (2, 42)
# Processing datasets (2, 11)
# Processing datasets (2, 4)
# Processing datasets (27, 56)
# Processing datasets (17, 19)
# Processing datasets (18, 56)
# Processing datasets (20, 23)
# Processing datasets (20, 21)
# Processing datasets (10, 13)
# Processing datasets (16, 42)
# Processing datasets (8, 33)
# Processing datasets (9, 12)
# Processing datasets (32, 51)
# Processing datasets (6, 12)
# Processing datasets (10, 39)
# Processing datasets (51, 56)
# Processing datasets (9, 15)
# Processing datasets (24, 33)
# Processing datasets (9, 17)
# Processing datasets (20, 25)
# Processing datasets (8, 20)
# Processing datasets (16, 39)
# Processing datasets (2, 36)
# Processing datasets (48, 55)
# Processing datasets (20, 45)
# Processing datasets (9, 45)
# Processing datasets (13, 27)
# Processing datasets (12, 39)
# Processing datasets (26, 48)
# Processing datasets (26, 40)
# Processing datasets (25, 26)
# Processing datasets (15, 28)
# Processing datasets (8, 40)
# Processing datasets (3, 15)
# Processing datasets (17, 28)
# Processing datasets (14, 42)
# Processing datasets (0, 14)
# Processing datasets (8, 13)
# Processing datasets (44, 52)
# Processing datasets (8, 39)
# Processing datasets (24, 40)
# Processing datasets (5, 20)
# Processing datasets (23, 43)
# Processing datasets (23, 29)
# Processing datasets (37, 39)
# Processing datasets (9, 23)
# Processing datasets (30, 34)
# Processing datasets (19, 30)
# Processing datasets (9, 41)
# Processing datasets (23, 42)
# Processing datasets (2, 38)
# Processing datasets (20, 34)
# Processing datasets (17, 40)
# Processing datasets (17, 23)
# Processing datasets (11, 15)
# Processing datasets (50, 52)
# Processing datasets (41, 56)
# Processing datasets (53, 54)
# Processing datasets (42, 54)
# Processing datasets (26, 47)
# Processing datasets (10, 40)
# Processing datasets (14, 37)
# Processing datasets (20, 27)
# Processing datasets (17, 42)
# Processing datasets (17, 32)
# Processing datasets (4, 57)
# Processing datasets (41, 45)
# Processing datasets (2, 46)
# Processing datasets (2, 5)
# Processing datasets (40, 56)
# Processing datasets (43, 57)
# Processing datasets (39, 46)
# Processing datasets (34, 46)
# Processing datasets (19, 53)
# Processing datasets (11, 17)
# Processing datasets (21, 57)
# Processing datasets (33, 52)
# Processing datasets (14, 27)
# Processing datasets (29, 36)
# Processing datasets (29, 35)
# Processing datasets (48, 54)
# Processing datasets (16, 32)
# Processing datasets (5, 39)
# Processing datasets (22, 30)
# Processing datasets (24, 26)
# Processing datasets (27, 42)
# Processing datasets (9, 16)
# Processing datasets (22, 43)
# Processing datasets (2, 8)
# Processing datasets (29, 42)
# Processing datasets (12, 29)
# Processing datasets (15, 50)
# Processing datasets (6, 55)
# Processing datasets (23, 30)
# Processing datasets (11, 38)
# Processing datasets (3, 9)
# Processing datasets (52, 57)
# Processing datasets (3, 40)
# Processing datasets (28, 29)
# Processing datasets (16, 40)
# Processing datasets (25, 53)
# Processing datasets (39, 45)
# Processing datasets (30, 55)
# Processing datasets (30, 38)
# Processing datasets (22, 40)
# Processing datasets (12, 17)
# Processing datasets (11, 44)

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial, X_scanorama

# %%
sc.pp.neighbors(adata, use_rep="X_scanorama")
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=["Cluster", "batch"])

# %% [markdown]
# # Integrate image and segmentation mask data

# %% [markdown]
# ### User input
#
# *Previous to **commit e03e83d38317f2ca379851badd8b0f6896474f94**, the input was based on a single sample folder, containing one folder per point/FOV, containing all the image files (.tiff) of each channel*

# %%
# The user must choose 3 fluorophore channels to use as RGB raster format
user_input_channels = ['145_CD45', '174_CK', '113_vimentin'] #, '167_CD8', '143_CD4']
image_dir = 'input-data/raw-data/Hartmann-2021/scMEP_MIBI_singlecell/scMEP_MIBI_colon_images/'
segmentation_dir = "input-data/raw-data/Hartmann-2021/scMEP_MIBI_singlecell/segmentation/"

# %% [markdown]
# ### Algorithm initiation and adding images
#
#  - This algorithm processes both images and segmentation masks separately
#  - It also checks that the file names are correctly attributed based on `obs['library_id']`

# %%
def increase_contrast(arr, lower_thresh = 0, upper_thresh=0):
    '''
    Increase the contrast of an image by:
     - removing a lower threshold of values
     & assigning values above an upper threshold the maximum value
     & stretching the values to the entire uint8 space
    '''
    arr = (arr > lower_thresh) * arr
    arr = np.where(arr < upper_thresh, arr, [upper_thresh] * len(arr))
    arr = (arr - np.min(arr)) * (255 / (np.max(arr) - np.min(arr)))

    return arr

# %%
# Initialize the spatial dictionary
spatial_dict = {}

# Some variables
library_ids = adata.obs['library_id'].unique()

for donor in os.listdir(image_dir):

    donor_path = os.path.join(image_dir, donor)

    # Check if folder structure correct: layer 1
    if not os.path.isdir(donor_path):
        raise Exception('`image_dir` directory must only contain directories named after the donors.')
    
    # Check if folder names coincide with donor value in obs matrix
    elif not all(np.in1d(donor, adata.obs['donor'].to_list())):
        raise Exception('First layer folders are not named as in obs[\'donor\']')
    
    else:

        # Define points/FOV
        points = sorted(os.listdir(donor_path))

        # Check that point names are found in the `obs['library_id']`
        if not all(np.in1d(points, library_ids)):
            raise Exception("Image file names must be named equal to library_ids")




        # Add images
        
        for point in points:
    
            # Init dict layer 1: 'library_id' = {images, scalefactors}
            spatial_dict[point] = {}

            # Init dict layer 2: 'images' = {hires, segmentation}
            spatial_dict[point]['images'] = {}
    
            # Fill 'image' key in layer 2
            # 3 channel images as RGB raster 
            # Read .tif data as array
            # channel_arr = np.array(
                # [plt.imread(os.path.join(donor_path, point, user_input_channels[i]) + ".tif") for i in range(len(user_input_channels))]
            # ).transpose(1, 2, 0)
            c1 = plt.imread(os.path.join(donor_path, point, user_input_channels[0]) + ".tif")
            c2 = plt.imread(os.path.join(donor_path, point, user_input_channels[1]) + ".tif")
            c3 = plt.imread(os.path.join(donor_path, point, user_input_channels[2]) + ".tif")

            # Image transformation

            ## Only one channel to have information per pixel
            c3 = c3
            c2= np.where((c3 > 0), 0, c2)
            c1= np.where((c3 > 0) | (c2 > 0), 0, c1)

            ## Scale and stretch values to 8bit dtype=uint8
            c1 = np.log1p(c1) * (255 / np.log1p(255))
            c2 = np.log1p(c2) * (255 / np.log1p(255))
            c3 = np.log1p(c3) * (255 / np.log1p(255))

            ## Change contrast
            c1 = increase_contrast(c1, 0, 200)
            c2 = increase_contrast(c2, 0, 90)
            c3 = increase_contrast(c3, 120, 180)

            # Combinatorial superimposition for pseudo CMYK space
            c1n = np.where(c3 > 120, c3, c2)
            c2n = np.where(c3 > 120, c3, c1)
            c3n = np.where(c2 > 80, c2, c1)

            # # Back to int
            c1n = c1.astype('int')
            c2n = c2.astype('int')
            c3n = c3.astype('int')
    
            channel_arr = np.array([c1n, c2n, c3n], dtype='uint8').transpose(1, 2, 0)

            spatial_dict[point]['images']['hires'] = channel_arr
    
            # Fill 'scalefactors' key in layer 1
            spatial_dict[point]['scalefactors'] = {
                'spot_diameter_fullres': 15,
                'tissue_hires_scalef': 1, # Can be set to a specific scalefactor e.g. 400um/1024px but current workflow relies on =1
            }

# %% [markdown]
# ### Add segmentation data
#
# - This algorithm processes both images and segmentation masks separately
# - Checks the validity of the segmentation files by trying to attribute the their names to the corresponding image file names by string content.
#
# - In the future maybe integrate two alterntive paths:
#     - argument indicating a dictionary of file links
#     - argument indicating the file name changes/presuffixes that apply to the image file name to arrive at the segmentation file name

# %%
# Check if segmentation file names contain the library_id
seg_files = sorted(os.listdir(segmentation_dir))

## Initiate segmentation-file-name to library_id dict
dict_seg_lib_id = {}

for seg_file in seg_files:

    seg_id = seg_file[:-15] ### !!! Can be improved via e.g. regular expressions

    if seg_id in set(library_ids):
        dict_seg_lib_id[seg_file] = seg_id

    else:
        raise Exception('All segmentation files must contain the of an image file which are based on obs[\'library_id\']')


# Add segmentation information
for key, value in dict_seg_lib_id.items():

    # Fill 'segmentation' key in layer 2
    spatial_dict[value]['images']['segmentation'] = plt.imread(segmentation_dir + key)
    
    # Add 'tissue_segmentation_scalef' key in layer 1
    spatial_dict[value]['scalefactors']['tissue_segmentation_scalef'] = 1

# %% [markdown]
# ### Final segmentation integration

# %%
# Integrate spatial dictionary into adata
adata.uns['spatial'] = spatial_dict

# %% [markdown]
# # Save adata object

# %%
#adata.write('output-data/Hartmann-2021/hartmann.h5ad', compression='gzip')

# %% [markdown]
# # NCEM
#
# Output:
#  - Coupling analysis: DEGs
#  - Coupling analysis circular: DEGs or magnitude
#  - Sender effect on receiving cell
#  - Sender-receiver vulcano plot
#  - **Sender similarity analysis**
#
# Not functioning:
#  - Grid searches over neighbourhood sizes + Length scales of dependencies for different target cell-types
#  - (Squidpy CellPhoneDB)
#
# Outlook:
# - Future custom loader

# %%
import ncem

# %% [markdown]
# ### Custom directional sender-receiver interactions
#
# `cusom_effect_graph()`

# %%
# Custom wrapper function
def custom_effect_graph(
    data_loader: str=None,
    data_path: str=None,
    radius: int=35,
    n_eval_nodes: int=10,
    qval_thresh: float=0.05, 
    l1_thresh: int=0,
    fc_thresh: tuple=[0.00, 0.00],
    l2_thresh = 0,
    plot: bool=True
    ):
    ''''
    Calculates a custom sender-receiver graph based on interpreter.sender_effect()
     affected gene numbers per sender-receiver pair.

    Prerequisites:
     - import ncem
     - know what data loader you want to use
     - spatial data directories and files structured after the data loaders structure

    Input
     - Spatial features data
     - Parameters:
        - qval_thresh: FDR corrected p-value to be used as an upper-bound significance threshold
           (both L1 and L2 arrays)
        - l1_thresh: Minimum number of significant genes threshold for the L1 array.
        - fc_thresh:
            - Option 1: a list of two int or float numbers to be used as an upper-bound (first number)
               and lower-bound (second number)
               thresholds for the original coefficient values (only applied to L2 array).
            - Option 2: an int or float number. Assuming a normal distribution of coefficient values,
               the number indicates the standard deviation to be used as a cutoff. Only values above and
               below the mean +/- the standard deviation will be included (only on L2 norm array).
        - l2_thresh:
            - Option 1: Lower-bound threshold for computed L2 norm values (L2 array only).
            - Option 2: Use a specific percentile as a lower-bound threshold for computed
               L2 norm values (L2 array only).
               Notation str('AXX'), where 'A' is short for 'Above' and the 'XX' are strictly
               two numbers (int) to be considered as the lower-bound percentile threshold.

    Output:
     - List of 2 numpy arrays:
        - 1. Type-coupling (Sender-receiver effect) interaction matrix
            L1 norm of the number of significant interaction terms per cell
        - 2. Sender-receiver magnitude effect interaction matrix
            L2 norm of interacton term coefficients of genes per cell
        - dim(cell-types x cell-types)
            - [receiver, sender]
    '''

    # Load in the data using a specific data loader
    interpreter = ncem.interpretation.interpreter.InterpreterInteraction()
    interpreter.get_data(
        data_origin=data_loader, # Reference to specfic DataLoader (see notes in Dropbox paper)
        data_path=data_path,
        radius=radius,
        node_label_space_id='type',
        node_feature_space_id='standard',
    )

    # Extracting sender-receiver effects with NCEM
    interpreter.split_data_node(0.1, 0.1)
    interpreter.n_eval_nodes_per_graph = n_eval_nodes
    interpreter.cell_names = list(interpreter.data.celldata.uns['node_type_names'].values())

    # Compute sender receiver effects
    interpreter.get_sender_receiver_effects()


    # Some relevant variables
    clusters = interpreter.cell_names
    num_clusters = len(clusters)
    vars = interpreter.data.var_names
    num_vars = len(vars)
    qvals = interpreter.qvalues

    # interpreter.fold_change
    #  - numpy array of shape [8, 8 , 36] = [receiver clusters, sender clusters, features]
    #  - dtype=float32



    # L1-signigicance interaction matrix

    l1_effects = interpreter.fold_change

    # Filter out genes under corrected qval
    l1_effects = l1_effects * (qvals < qval_thresh)

    # L1 norm AKA Count genes > 0 per sender-receiver pair
    l1_effects = np.sum(l1_effects != 0, axis=2)

    # Filter out sender-receiver effects A.K.A node edges > nr_genes_thresh
    l1_effects = np.where(l1_effects > l1_thresh, l1_effects, np.zeros([num_clusters, num_clusters]))

    np.fill_diagonal(l1_effects, 0)



    # L2-coefficient interaction matrix

    l2_effects = interpreter.fold_change

    # Filter out genes under/over fc_thresh

    try:

        if isinstance(fc_thresh, list) & (len(fc_thresh) == 2) & isinstance(fc_thresh[0], (int, float)) & isinstance(fc_thresh[1], (int, float)):

            l2_effects = np.where((l2_effects < fc_thresh[0]) | (l2_effects > (fc_thresh[1])), l2_effects, np.zeros([num_clusters, num_clusters, num_vars]))

    except: 

        if isinstance(fc_thresh, (int, float)):
            
            mean = np.mean(l2_effects)
            std = np.std(l2_effects)

            l2_effects = np.where((l2_effects < (mean - (fc_thresh * std))) | (l2_effects > (mean + (fc_thresh * std))), l2_effects, np.zeros([num_clusters, num_clusters, num_vars]))
        
        else:
            raise Exception(f'{fc_thresh} doesnt comply with possible parameter types.')


    # Filter out genes under corrected qval
    l2_effects = l2_effects * (qvals < qval_thresh)

    # L2 norm
    l2_effects = np.sqrt(np.sum(l2_effects ** 2, axis=-1))

    # Filter out sender-receiver effects A.K.A L2 score > l2_thresh
    if isinstance(l2_thresh, (int, float)):

        l2_effects = np.where(l2_effects > l2_thresh, l2_effects, np.zeros([num_clusters, num_clusters]))
    
    elif isinstance(l2_thresh, str) & len(l2_thresh) == 3:
        
        try:

            _ = l2_thresh[0] == 'A'
            int_number = int(l2_thresh[1, 3])

            percentile =  np.percentile(l2_effects, int_number)

            l2_effects = np.where(l2_effects > percentile, l2_effects, np.zeros([num_clusters, num_clusters]))


        except ValueError:

            print('l2_thresh doesnt comply with the parameter possibilities.')
    
    else:

        print('l2_thresh doesnt comply with the parameter possibilities.')

    np.fill_diagonal(l2_effects, 0)


    # Heatmap
    if plot == True:

        fig, (ax0, ax1) = plt.subplots(1, 2, sharex=True)

        im0 = ax0.imshow(l1_effects, cmap='gray_r')
        im1 = ax1.imshow(l2_effects, cmap='gray_r')
        ax0.set_title('Sender-receiver effects:\nL1(significance)')
        ax1.set_title("Sender-receiver effects:\nL2(interaction terms)")

        for ax in fig.get_axes():
            
            ax.set_xlabel('Senders')
            ax.set_xticks([i for i in range(0,8)])
            ax.set_xticklabels(interpreter.cell_names, rotation=90)

            ax.set_ylabel('Receivers')
            ax.set_yticks([i for i in range(0,8)])
            ax.set_yticklabels(interpreter.cell_names)

            ax.label_outer()

        fig.colorbar(im0, ax=ax0, shrink=0.49)
        fig.colorbar(im1, ax=ax1, shrink=0.49)

        plt.show()

    return [l1_effects, l2_effects]

# %%
# Applying the function
ncem_custom_graph = custom_effect_graph(
    data_loader='hartmann',
    data_path='input-data/raw-data/Hartmann-2021/',
    radius=35,
    n_eval_nodes=10,
    qval_thresh=0.05,
    l1_thresh=0,
    fc_thresh=0,
    l2_thresh=0
)
# Out:
# Loading data from raw files
# registering celldata
# collecting image-wise celldata
# adding graph-level covariates
# 100%|██████████| 58/58 [00:01<00:00, 51.85it/s]
# Loaded 58 images with complete data from 4 patients over 63747 cells with 36 cell features and 8 distinct celltypes.
# Mean of mean node degree per images across images: 4.416036
# Using split method: node.
#  Train-test-validation split is based on total number of nodes per patients over all images.
#
# Excluded 0 cells with the following unannotated cell type: [None]
#
# Whole dataset: 63747 cells out of 58 images from 4 patients.
# Test dataset: 6376 cells out of 58 images from 4 patients.
# Training dataset: 51914 cells out of 58 images from 4 patients.
# Validation dataset: 5738 cells out of 58 images from 4 patients.
# 100%|█████████▉| 6351/6374 [00:26<00:00, 237.90it/s]
# using ols parameters.
# calculating inv fim.
